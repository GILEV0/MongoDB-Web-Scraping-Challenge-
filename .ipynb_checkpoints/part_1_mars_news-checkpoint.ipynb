# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import os

# %%
# Set the executable path and initialise the chrome browser in splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.58M/6.58M [00:05<00:00, 1.23MB/s]

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
soup = soup(browser.html, 'html.parser')

# %%
print(soup.get_text())
# Out:
# News - Mars Exploration Program
#
#
#
#
#
#
#
# MARS Planet Science
# Exploration Program
#
#
#
#
#
#
#
# The Red Planet
#
#
# The Program
#
#
# News & Events
#
#
# Multimedia
#
#
# Missions
#
#
# More
#
#
#
#
#
#
#
#
#
#
# News
#
#
#
#
#
#
#
#
# Latest
# 20192020
#
#
#
# All Categories
# Feature StoriesPress ReleasesStatus Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 17, 2022
# HiRISE Views NASA's InSight and Curiosity on Mars
# New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 17, 2022
# The MarCO Mission Comes to an End
# The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 16, 2022
# 10.9 Million Names Now Aboard NASA's Perseverance Mars Rover
# ...

# %%
news_title = soup.find("div", class_="content_title").text
news_preview = soup.find("div", class_="article_teaser_body").text
news_title
# Out:
# "HiRISE Views NASA's InSight and Curiosity on Mars"

# %%
news_preview
# Out:
# 'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.'

# %%
# Extract all the text elements
#  Extract all news articles text
slide_elems = soup.select('div.list_text')
slide_elems
# Out:
# [<div class="list_text">
#  <div class="list_date">December 17, 2022</div>
#  <div class="content_title">HiRISE Views NASA's InSight and Curiosity on Mars</div>
#  <div class="article_teaser_body">New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">December 17, 2022</div>
#  <div class="content_title">The MarCO Mission Comes to an End</div>
#  <div class="article_teaser_body">The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">December 16, 2022</div>
#  <div class="content_title">10.9 Million Names Now Aboard NASA's Perseverance Mars Rover</div>
# ...

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
mars_news_list = []

# %%
# Loop through the text elements
# Store each title and preview pair in a dictionary

for elem in slide_elems:
    # Extract the title and preview text from the elements    
    title = elem.find('div', class_='content_title').text
    preview = elem.find('div', class_='article_teaser_body').text
    
    # Add the dictionary to the list
    mars_news_list.append({'title': title, 'preview': preview})

# %%
# Print the list to confirm success
mars_news_list
# Out:
# [{'title': "HiRISE Views NASA's InSight and Curiosity on Mars",
#   'preview': 'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.'},
#  {'title': 'The MarCO Mission Comes to an End',
#   'preview': 'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.'},
#  {'title': "10.9 Million Names Now Aboard NASA's Perseverance Mars Rover",
#   'preview': "As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars."},
#  {'title': "NASA's Perseverance Rover Is Midway to Mars ",
#   'preview': "Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination."},
#  {'title': 'NASA to Hold Mars 2020 Perseverance Rover Launch Briefing',
# ...

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
import json
mars_news_json = json.dumps(mars_news_list)
print(mars_news_json)
# Out:
# [{"title": "HiRISE Views NASA's InSight and Curiosity on Mars", "preview": "New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along."}, {"title": "The MarCO Mission Comes to an End", "preview": "The pair of briefcase-sized satellites made history when they sailed past Mars in 2019."}, {"title": "10.9 Million Names Now Aboard NASA's Perseverance Mars Rover", "preview": "As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars."}, {"title": "NASA's Perseverance Rover Is Midway to Mars ", "preview": "Sometimes half measures can be a good thing \u2013 especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination."}, {"title": "NASA to Hold Mars 2020 Perseverance Rover Launch Briefing", "preview": "Learn more about the agency's next Red Planet mission
# ...

# %%
# store the scraped data in a csv file
mars_news_df = pd.read_json(mars_news_json)
mars_news_df.to_csv('mars_weather.csv',index=False)

# %%
# Export data to MongoDB
from pymongo import MongoClient

mongo = MongoClient(port=27017)
mongo.list_database_names()
# Out:
# ['admin', 'classDB', 'config', 'gardenDB', 'local', 'team_db', 'travel_db']
